# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# $$ЗАДАНИЕ1$$

# %%
x = np.array([1,5,10,100])
A=8
y = np.log(abs((np.exp(np.cos(x**A))*np.tan(x**2))/(A*x/9 + x**(3/2))))/np.log(2*x)
print(y)
# Out:
# [ 0.5011003  -1.71746508 -1.53463018 -1.50902983]

# %% [markdown]
# $$ЗАДАНИЕ 2$$

# %%
y1 = [0.002,0.003,0.004,0.005,0.007,0.01,0.017,0.020,0.024,0.027,0.031,0.036,0.043,0.048,0.055,0.06,0.066,0.073,0.082,0.091,0.095,0.1,0.104,0.108,0.110,0.111,0.112,0.112,0.112,0.113,0.113,0.113,0.113,0.113,0.113,0.113,0.113,0.113,0.112,0.112,0.112,0.111,0.110,0.109,0.106,0.103,0.099,0.095,0.091,0.088,0.080,0.073,0.067,0.061,0.056,0.052,0.047,0.042,0.036,0.032,0.025,0.021,0.018,0.016,0.013,0.011,0.008,0.007,0.006,0.005,0.004,0.003,0.003]
x = [300,700,1100,1400,1600,1800,2000,2050,2100,2125,2150,2175,2200,2215,2230,2240,2250,2260,2270,2280,2285,2290,2295,2300,2305,2307,2309,2310,2312,2313,2314,2315,2316,2317,2318,2319,2320,2321,2322,2324,2326,2328,2330,2335,2340,2345,2350,2355,2360,2370,2380,2390,2400,2410,2420,2435,2450,2475,2500,2550,2600,2650,2700,2800,2900,3000,3200,3400,3600,4000,4500,5000,5500]
R=100
e=0.2627
l=0.72
c=6.8*(10**(-9))
ur1=[]
for i in range(0,73):
    ur=(e*R)/(((R**2)+(2*np.pi*x[i]*l-1/(2*np.pi*x[i]*c))**2)**(1/2))
    ur1.append(ur)
plt.figure(figsize=(15, 10))
plt.errorbar(x, y1, xerr=50, yerr=0.005, label='$U_r(w){п}$')
plt.errorbar(x, ur1, xerr=50, yerr=0.005, label='$U_r(w){т}$')
plt.xlabel(r'$w, Гц$', fontsize=15)
plt.ylabel(r'$U_r, Ом$', fontsize=15)
plt.legend(loc='best', fontsize=10)
plt.grid()
plt.show()

# %%
#Задание 1
x = np.array([1,5,10,100])
A=3
y = np.log(abs((np.exp(np.cos(x**A))*np.tan(x**2))/(A*x/9 + x**(3/2))))/np.log(2*x)
print(y)
# Out:
# [ 1.00360065 -1.64113472 -1.1763669  -1.34763484]
