# %%
import numpy as np
x=[0]*(4)
x[0]=1
x[1]=5
x[2]=10
x[3]=100
for i in range(4):
    y=np.log(abs((np.exp(np.cos(x[i])**23)*np.tan(x[i]**2))/(23/9*x[i]+np.sqrt(x[i]**3)))) / np.log(2*x[i])
    print(y)
# Out:
# -1.1909272886007745
# -2.2538855305283096
# -1.5342548680595802
# -1.5549458922005697

# %% [markdown]
# Изучение двухполюсников
# $$z=R +jwL $$
# $$|z|= sqrt(R^2+(wL)^2) $$

# %%
import matplotlib.pyplot as plt
R=13000
L=1.25
x1=np.linspace(1,6000,100)
y1=np.sqrt(R**2+(x*L)**2)
plt.xlabel(r'Теоретический график зависимости |z| от частоты', fontsize=16)
plt.plot(x1,y1)
plt.grid()

# %%
import matplotlib.pyplot as plt
x = [15,100,500,1000,2000,3000,5000]
y = [13700,13690,13700,13800,13900,14100,15200]
R=13700
L=1.25
x1=np.linspace(1,5000,100)
y1=np.sqrt(R**2+(x1*L)**2)
plt.xlabel(r'Теоретический график зависимости |z| от частоты', fontsize=16)
plt.plot(x1,y1)
plt.errorbar(x, y, xerr=0.1, yerr=25)
plt.xlabel(r'Практический график зависимости |z| от частоты', fontsize=16)
plt.grid()
plt.plot(x,y)
plt.show()
