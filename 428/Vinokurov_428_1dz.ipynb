# %% [markdown]
# **Выполнил:** Винокуров Олег группа 428

# %% [markdown]
# **Подключаю библеотеки:**

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **Вычисляю:**

# %%
def y(x):
    return np.log(a)/np.log(2*x)
A=15
x=np.array([1,5,10,100])
a=abs((np.exp(np.cos(x**A))*np.tan(x**2))/(A*x/2 + x**1.5))
print(y(x))
# Out:
# [-1.6688247  -2.55680975 -1.61794977 -1.4753869 ]

# %% [markdown]
# **График:**

# %%
x = np.array([46, 121, 245, 352, 630]) #R
y = np.array([0.2, 0.35, 0.57, 0.74, 1.23]) #d

L = 104
C = 0.000046
def d(x):
    return np.pi*x*(C/L)**0.5

plt.figure(figsize = (15, 10))
plt.errorbar(x, y, xerr=0.01, yerr=0.02,color = "red", marker = "o", label = "$d_{прак}$")
plt.plot(x, d(x), color = "green", label = "$d_{теор}$")
plt.xlabel(r"$R, Ом$", fontsize=16)
plt.ylabel(r"$d$", fontsize=16)
plt.legend(loc = "best", fontsize = 20)
plt.grid()
plt.show()
